# %%
import sympy
from sympy import symbols

sympy.init_printing()

# %%
#求解Bellman方程

v_hungry,v_full = symbols('v_hungry v_full')
q_hungry_eat, q_hungry_none, q_full_eat, q_full_non = symbols('q_hungry_eat q_hungry_none q_full_eat q_full_non')
alpha, beta, gamma = symbols('alpha beta gamma')
x, y = symbols('x y')

system = sympy.Matrix(((1, 0, x-1, -x, 0, 0, 0),
                    (0, 1, 0, 0, -y, y-1, 0),
                    (-gamma, 0, 1, 0, 0, 0, -2),
                    ((alpha-1)*gamma, -alpha*gamma, 0, 1, 0, 0, 4*alpha-3),
                    (-beta*gamma, (beta-1)*gamma, 0, 0, 1, 0, 2-4*beta),
                    (0, -gamma, 0, 0, 0, 1, 1)))

sympy.solve_linear_system(system,v_hungry, v_full, q_hungry_none, q_hungry_eat, q_full_non, q_full_eat )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ff96cf7bee2c> in <module>
#       1 #求解Bellman方程
#       2
# ----> 3 v_hungry,v_full = symbols('v_hungry v_full')
#       4 q_hungry_eat, q_hungry_none, q_full_eat, q_full_non = symbols('q_hungry_eat q_hungry_none q_full_eat q_full_non')
#       5 alpha, beta, gamma = symbols('alpha beta gamma')
#
# NameError: name 'symbols' is not defined

# %%
#求解Bellman方程
xy_tuples = ((0,0),(1,0),(0,1),(1,1))
for x, y in xy_tuples:
    system = sympy.Matrix(((1, 0, x-1, -x, 0, 0, 0),
                    (0, 1, 0, 0, -y, y-1, 0),
                    (-gamma, 0, 1, 0, 0, 0, -2),
                    ((alpha-1)*gamma, -alpha*gamma, 0, 1, 0, 0, 4*alpha-3),
                    (-beta*gamma, (beta-1)*gamma, 0, 0, 1, 0, 2-4*beta),
                    (0, -gamma, 0, 0, 0, 1, 1)))
    result = sympy.solve_linear_system(system, v_hungry, v_full, q_hungry_none, q_hungry_eat, q_full_non, q_full_eat, simplification = True)
    msgx = 'v(饿) = q(饿，{}吃)'.format(''if x else '不')
    msgy = 'v(饱) = q(饱，{}吃)'.format('不'if y else '')
    print('==== {}, {} ==== x = {}, y = {} ===='.format(msgx, msgy, x, y))
    display(result)
# Out:
# ==== v(饿) = q(饿，不吃), v(饱) = q(饱，吃) ==== x = 0, y = 0 ====
# ⎧             -1                -β⋅γ + 4⋅β + γ - 2                α⋅γ - 4⋅α -
# ⎨q_full_eat: ─────, q_full_non: ──────────────────, q_hungry_eat: ────────────
# ⎩            γ - 1                    γ - 1                             γ - 1
#
# γ + 3                   2             -1                2  ⎫
# ─────, q_hungry_none: ─────, v_full: ─────, v_hungry: ─────⎬
#                       γ - 1          γ - 1            γ - 1⎭
# ==== v(饿) = q(饿，吃), v(饱) = q(饱，吃) ==== x = 1, y = 0 ====
# ⎧                                  2                          2
# ⎪             -1                α⋅γ  - 2⋅α⋅γ - 4⋅β⋅γ + 4⋅β - γ  + 3⋅γ - 2
# ⎨q_full_eat: ─────, q_full_non: ─────────────────────────────────────────, q_h
# ⎪            γ - 1                         2          2
# ⎩                                       α⋅γ  - α⋅γ - γ  + 2⋅γ - 1
#
#                                                              2            2
# ...
